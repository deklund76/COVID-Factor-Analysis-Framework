# %%
import pandas as pd
import epiweeks

# %%
raw_gender_df = pd.read_csv('gender_data_raw.csv')

# %%
columns_to_drop = ['male_case_rate',
            'female_case_rate','male_death_rate',
            'female_death_rate']

# %%
raw_gender_df.drop(columns_to_drop, axis=1)
raw_gender_df
# Out:
#            location   date cases_total male_cases female_cases  \
# 0           Alabama   4/13       4,572       1876         2615
# 1            Alaska   4/13         272        134          138
# 2           Arizona   4/13        3539       1663         1876
# 3          Arkansas   4/13        1280        552          728
# 4       California    4/13      21,794      10926        10571
# ...             ...    ...         ...        ...          ...
# 4447       Virginia  11/20      953460     451359       489277
# 4448     Washington  11/20      762118     368103       373590
# 4449  West Virginia  11/20      288967     135934       149995
# 4450      Wisconsin  11/20      844598     407479       435460
# 4451        Wyoming  11/20      109318      41221        43313
#
#      percent_male_cases percent_female_cases male_case_rate female_case_rate  \
# 0                 41.03                57.20          79.63           104.24
# ...
