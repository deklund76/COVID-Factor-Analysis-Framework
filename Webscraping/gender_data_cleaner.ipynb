# %%
import pandas as pd
import epiweeks

# %%
raw_gender_df = pd.read_csv('raw_gender_data.csv')

# %%
raw_gender_df
# Out:
#                                location                                 date  \
# 0          <td class="s11">Alabama</td>  <td class="s12" dir="ltr">4/13</td>
# 1           <td class="s11">Alaska</td>  <td class="s12" dir="ltr">4/13</td>
# 2          <td class="s11">Arizona</td>  <td class="s12" dir="ltr">4/13</td>
# 3         <td class="s11">Arkansas</td>  <td class="s12" dir="ltr">4/13</td>
# 4      <td class="s11">California </td>  <td class="s12" dir="ltr">4/13</td>
# ..                                  ...                                  ...
# 101       <td class="s11">Virginia</td>  <td class="s12" dir="ltr">4/27</td>
# 102     <td class="s11">Washington</td>  <td class="s12" dir="ltr">4/27</td>
# 103  <td class="s11">West Virginia</td>  <td class="s12" dir="ltr">4/27</td>
# 104      <td class="s11">Wisconsin</td>  <td class="s12" dir="ltr">4/27</td>
# 105        <td class="s11">Wyoming</td>  <td class="s12" dir="ltr">4/27</td>
#
#                               cases_total  \
# ...
